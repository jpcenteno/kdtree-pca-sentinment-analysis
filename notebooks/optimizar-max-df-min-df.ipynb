# %% [markdown]
# La experimentación sobre `max_df` y `min_df` fue llevada a cabo con el script `optimizar-max-df-min-df.py`. Esta notebook solo se encarga de graficar los resultados.

# %%
import itertools
import time

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('results/resultados-opti-max-df-min-df.csv')
df.head()
# Out:
#    max_df  min_df       acc       time
# 0     0.4   0.001  0.742948  99.415290
# 1     0.4   0.025  0.690359  18.994696
# 2     0.4   0.050  0.704382  11.349690
# 3     0.4   0.075  0.700558   9.191387
# 4     0.4   0.100  0.676494   7.813484

# %%
# Total elapsed time:
time_secs = df['time'].sum()
time.strftime('%H:%M:%S', time.gmtime(time_secs))
# Out:
# '00:23:39'

# %%
# Grafica el resultado
def plot(df):
    df = df.drop_duplicates(['max_df', 'min_df'])
    acc = df.pivot('max_df', 'min_df', 'acc')
    plt.figure(figsize=(20,10))
    sns.heatmap(acc, annot=True, fmt="0.4f", linewidths=.5)
    
plot(df)
plt.savefig('plots/exp_maxmindf.png')
plt.show()
